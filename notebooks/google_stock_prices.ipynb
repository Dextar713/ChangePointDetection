# %%
import pandas as pd
from matplotlib import pyplot as plt
from utilsforecast.plotting import plot_series

df = pd.read_csv('../data/gafa_stock.csv')
df['ds'] = pd.to_datetime(df['ds'])
#print(df['unique_id'].value_counts())
google_df = df[df['unique_id'].str.startswith('GOOG')]
#print(google_df.head())
# fig, ax = plt.subplots(nrows=1, ncols=1)
fig = plot_series(
    df = google_df,
    id_col = 'unique_id',
    time_col= 'ds',
    target_col= 'y',
)
fig

# %%
closing_prices = df[df['unique_id'].str.endswith('CLOSE')]
best_days = closing_prices.groupby
