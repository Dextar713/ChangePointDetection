# %%
import pandas as pd
from utilsforecast.plotting import plot_series
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')

# %%
# amd = yf.Ticker("AMD")
daily_data = yf.download(tickers='AMD', period='1y', interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
daily_data.to_csv('../data/amd_1y_5dec.csv')

# %%
daily_data.columns = daily_data.columns.droplevel(1)
print(daily_data.columns)
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %%
daily_data[:2]
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2024-12-05  141.360001  143.949997  140.380005  143.679993  29576900
# 2024-12-06  138.589996  142.789993  137.399994  141.479996  33576800

# %%
melt_df = daily_data.reset_index().melt(id_vars='Date', var_name='unique_id', value_name='y')
print(melt_df[:2])
fig = plot_series(df=melt_df, id_col='unique_id', target_col='y', time_col='Date')
fig
# Out:
#         Date unique_id           y
# 0 2024-12-05     Close  141.360001
# 1 2024-12-06     Close  138.589996
